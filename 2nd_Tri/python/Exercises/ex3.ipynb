# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

data = pd.read_csv("https://raw.githubusercontent.com/leonkag/Statistics0/main/MHEALTH.csv")
dataset = data

print(dataset.head(10))

dataset.columns = dataset.columns.str.strip()
# Out:
#     MALE  AGE    HT     WT  WAIST  PULSE  SYS  DIAS  CHOL   BMI  LEG   ELBOW  \
# 0   7190   20  69.7  137.4   75.2     88  112    44   139  19.9  44.8    6.9
# 1   4832   25  67.6  151.3   75.6     64  119    81   265  23.3  41.0    7.0
# 2  19635   34  63.7  119.5   75.7     56  125    77   277  20.7  42.6    6.6
# 3   7194   29  70.0  162.4   77.0     56  116    64   613  23.4  43.1    7.5
# 4   2129   22  66.2  144.2   78.1     64  107    54   127  23.2  40.2    7.6
# 5   2989   41  66.5  135.0   78.8     60  113    71   590  21.5  43.4    6.5
# 6   9074   26  68.5  144.1   79.6     64  110    70   303  21.6  41.0    6.8
# 7  32230   20  66.3  151.0   79.9     72  115    65   172  24.2  44.0    7.1
# 8  19381   36  70.3  137.1   81.6     64  112    77   176  19.6  40.8    7.1
# 9   3607   54  65.6  139.0   82.5     60  110    71   578  22.7  36.0    6.9
#
#    WRIST   ARM
# 0    5.6  25.9
# 1    5.7  30.6
# 2    5.3  26.9
# 3    5.2  30.3
# 4    6.2  31.0
# 5    5.2  27.6
# ...

# %%
dataset.info()
print(dataset.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MALE    40 non-null     int64
#  1   AGE     40 non-null     int64
#  2   HT      40 non-null     float64
#  3   WT      40 non-null     float64
#  4   WAIST   40 non-null     float64
#  5   PULSE   40 non-null     int64
#  6   SYS     40 non-null     int64
#  7   DIAS    40 non-null     int64
#  8   CHOL    40 non-null     int64
#  9   BMI     40 non-null     float64
#  10  LEG     40 non-null     float64
#  11  ELBOW   40 non-null     float64
#  12  WRIST   40 non-null     float64
#  13  ARM     40 non-null     float64
# dtypes: float64(8), int64(6)
# memory usage: 4.5 KB
#                MALE        AGE         HT          WT       WAIST      PULSE  \
# count     40.000000  40.000000  40.000000   40.000000   40.000000  40.000000
# ...

# %%
print("Mean:",dataset['PULSE'].mean())
print("Median:",dataset['PULSE'].median())
print("Mode:",dataset['PULSE'].mode()[0])
# Out:
# Mean: 69.4
# Median: 66.0
# Mode: 60

# %%
dataset["PULSE"].fillna(dataset["PULSE"].mean(), inplace=True)
print(dataset.isnull().sum())
dataset.head(20)
# Out:
# MALE     0
# AGE      0
# HT       0
# WT       0
# WAIST    0
# PULSE    0
# SYS      0
# DIAS     0
# CHOL     0
# BMI      0
# LEG      0
# ELBOW    0
# WRIST    0
# ARM      0
# dtype: int64
# C:\Users\varun\AppData\Local\Temp\ipykernel_4700\4023033038.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["PULSE"].fillna(dataset["PULSE"].mean(), inplace=True)
#      MALE  AGE    HT     WT  WAIST  PULSE  SYS  DIAS  CHOL   BMI   LEG  ELBOW  \
# ...
